# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

# %load_ext autoreload
# %aimport util
from util import *
# %autoreload 1

from PIL import Image
from IPython.display import display

# %%
def load_dataset():
    delighted_data = {}
    for mesh, mesh_dir in delighted_dirs.items():
        mesh_im = Image.open(mesh_dir + '%s_HD_BC.tga' % mesh, 'r')
#         mesh_im = mesh_im.resize((256, 256), Image.ANTIALIAS)
        mesh_array = zero_rgb(np.array(mesh_im))
        mesh_array = mesh_array[:,:,:3]
        delighted_data[mesh] = mesh_array

    lighted_data = []
    lighted_alpha_data = []
    for t, mesh, v, mesh_dir in lighted_dirs:
        lit_file = '%s%s_%s_%s_Lit.tga' % (mesh_dir, t, mesh, v)
        if not os.path.exists(lit_file):
            continue
        mesh_im = Image.open(lit_file, 'r')
        # resize according to shapenet
#         mesh_im = mesh_im.resize((256, 256), Image.ANTIALIAS)
        alphas = np.array(mesh_im)[:,:,3]
        alphas = alphas / alphas.max(axis=0)

        meshes = np.array(mesh_im)[:,:,:3]
        lighted_data.append((mesh, meshes))
        lighted_alpha_data.append((mesh, alphas))
        
    return delighted_data, lighted_data, lighted_alpha_data


#unused method to scale from 0 to 1~ish
def preproc(unclean_batch_x):
    """Convert values to range 0-1"""
    temp_batch = unclean_batch_x / unclean_batch_x.max()
    return temp_batch

def shuffle(lighted_inputs, lighted_alpha_inputs):
    inputs = []
    alpha_inputs = []
    indices = np.random.choice(len(lighted_inputs), len(lighted_inputs), replace = False)
    for i in indices:
        tup = lighted_inputs[i]
        tup_alpha = lighted_alpha_inputs[i]
        inputs.append(tup)
        alpha_inputs.append(tup_alpha)
        
    return inputs, alpha_inputs

# %%
date_dir = 'data/'
delighted_dirs, lighted_dirs = scan_lighted_delighted(date_dir)

delighted_data, lighted_data, lighted_alpha_data = load_dataset()
# Out:
# /Users/quinntran/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:20: RuntimeWarning: divide by zero encountered in divide

# %%
lighted_default_alpha_data = []

for i in range(len(lighted_alpha_data)):
    mesh, alphas = lighted_alpha_data[i][0], lighted_alpha_data[i][1]
    lighted_default_alpha_data.append((mesh, np.ones(alphas.shape)))

# %%
def conv2d(x, W, b, stride):
    x = tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='SAME') + b
#     x = tf.contrib.layers.batch_norm(x, center=True, scale=True)
    return tf.nn.relu(x)

def deconv2d(x, W, b, stride):
    x = tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='SAME') + b
#     x = tf.contrib.layers.batch_norm(x, center=True, scale=True)
    x = tf.nn.relu(x)
    
    # bilinear interpolation upsampling
    old_height, old_width = x.get_shape().as_list()[1 : 3]
    scale = 2
    new_height = old_height * scale
    new_width = old_width * scale
    return tf.image.resize_images(x, [new_height, new_width], method=tf.image.ResizeMethod.BILINEAR)

ENCODER = 'encoder'
MID = 'mid'
DECODER = 'decoder'

def get_dimension_name(stage, layer_num):
    return 'dims_' + stage + '_' + str(layer_num)

def get_weight_name(stage, layer_num):
    return 'w_' + stage + '_' + str(layer_num)
    
def get_bias_name(stage, layer_num):
    return 'b_' + stage + '_' + str(layer_num)

# %%
# Store layers weight & bias
# more parameters
FILTER_SIZE = 5 #try 7 if 5 doesn't work
INPUT_DEPTH = 3

# output depths of the layers
ENCODER_DEPTHS = [4, 8, 16]
MID_DEPTH = ENCODER_DEPTHS[-1]
DECODER_DEPTHS = [8, 4, 3]

# defines the sizes for each of the conv / deconv layers
layer_dimensions = {}
prev_depth = INPUT_DEPTH
for i, output_depth in enumerate(ENCODER_DEPTHS):
    weight_name = get_dimension_name(ENCODER, i)
    stride = 1 if i == 0 else 2 # stride 1 for the first conv layer only
    layer_dimensions[weight_name] = {
        'input_depth' : prev_depth,
        'output_depth' : output_depth,
        'stride' : stride,
        'filter_size' : FILTER_SIZE
    }
    prev_depth = output_depth

for i in range(1):
    weight_name = get_dimension_name(MID, i)
    layer_dimensions[weight_name] = {
        'input_depth' : MID_DEPTH,
        'output_depth' : MID_DEPTH,
        'stride' : 1,
        'filter_size' : FILTER_SIZE
    }

prev_depth = MID_DEPTH
for i, output_depth in enumerate(DECODER_DEPTHS):
    # the ith deconv layer's input is the concatenation of the previous output and the output of (2-i)th encoder conv layer
    # so the depth is the sum of the depths
    # the last two layers in this loop (5th and 6th layer) are conv layers, not deconv
    if i < 2:
        prev_encoder_depth = ENCODER_DEPTHS[2 - i]
        input_depth = prev_depth + prev_encoder_depth
    else: # 3rd layer doesn't have concatenation
        input_depth = prev_depth
    weight_name = get_dimension_name(DECODER, i)
    layer_dimensions[weight_name] = {
        'input_depth' : input_depth,
        'output_depth' : output_depth,
        'stride' : 1,
        'filter_size' : FILTER_SIZE
    }
    prev_depth = output_depth

# %%
class IntrinsicNetwork(object):
    def __init__(self, input_dimensions, dimensions, learning_rate=1e-3, checkpoint_file=None):
        graph = tf.Graph()
        self.sess = tf.InteractiveSession(graph=graph)
        
        self.dimensions = dimensions
        self.params = {}
        
        #input will be 1024x1024x3
        self.inp = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        self.expected_output = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        
        encoder_layers = self.get_encoder_layers(self.inp)
        mid_output = self.get_mid_output(encoder_layers[-1])
        self.output = self.get_decoder_output(mid_output, encoder_layers)
        
        self.loss = tf.reduce_mean(tf.squared_difference(self.output, self.expected_output))
        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
        if checkpoint_file:
            saver = tf.train.Saver()
            saver.restore(self.sess, checkpoint_file)
        else:
            init = tf.global_variables_initializer()
            self.sess.run(init)
    
    def create_weights(self, stage, layer_num):
        dims = self.dimensions[get_dimension_name(stage, layer_num)]
        input_depth, output_depth, stride, filter_size = \
            (dims[x] for x in ['input_depth', 'output_depth', 'stride', 'filter_size'])
#         W = tf.Variable(tf.random_normal([filter_size, filter_size, input_depth, output_depth]))
        W = tf.get_variable(get_weight_name(stage, layer_num), shape=[filter_size, filter_size, input_depth, output_depth], 
                            initializer=tf.contrib.layers.xavier_initializer())
        b = tf.Variable(tf.random_normal([output_depth]))
        self.params[get_weight_name(stage, layer_num)] = W
        self.params[get_bias_name(stage, layer_num)] = b
        return W, b, stride
        
    def get_encoder_layers(self, inpt):
        prev = inpt
        encoder_layers = []
        # encoder layers 0 to 2
        for layer_num in range(3):
            W, b, stride = self.create_weights(ENCODER, layer_num)
            prev = conv2d(prev, W, b, stride)
            encoder_layers.append(prev)
        return encoder_layers
    
    def get_mid_output(self, encoder_output):
        prev = encoder_output
        for layer_num in range(1):
            W, b, stride = self.create_weights(MID, layer_num)
            prev = conv2d(prev, W, b, stride)
        return prev
        
    def get_decoder_output(self, mid_outputs, encoder_layers):
        prev = mid_outputs
        for layer_num in range(3):
            W, b, stride = self.create_weights(DECODER, layer_num)
            if layer_num < 2:
                encoder_layer_input = encoder_layers[2 - layer_num]
                prev = tf.concat([prev, encoder_layer_input], axis=3)
                prev = deconv2d(prev, W, b, stride)
            else:
                prev = conv2d(prev, W, b, stride)
        return prev
    
    def fit_batch(self, inputs, output):
        _, loss = self.sess.run((self.optimizer, self.loss), feed_dict={self.inp : inputs, self.expected_output : output})
        return loss
    
    def train(self, lighted_inputs, delighted_data, epochs, batch_size=1, display_step=5):
        random.shuffle(lighted_inputs)
        n_samples = len(lighted_inputs)
        mean_losses = []
        for epoch in range(epochs):
            total_iter = n_samples // batch_size
            total_loss = 0
            for i in range(total_iter):
                meshes, inputs = zip(*lighted_inputs[i * batch_size : (i + 1) * batch_size])
                inputs = np.asarray(inputs)
                expected_outputs = np.asarray([delighted_data[mesh] for mesh in meshes])
                loss = self.fit_batch(inputs, expected_outputs)
                total_loss += loss
            mean_loss = total_loss / total_iter
            mean_losses.append(mean_loss)
            if (epoch + 1) % display_step == 0:
                print('epoch %s: loss=%.4f' % (epoch + 1, mean_loss))
                
    def predict(self, inputs):
        return self.sess.run(self.output, feed_dict={self.inp : inputs})
    
    def save(self, save_path):
        saver = tf.train.Saver()
        saver.save(self.sess, save_path)

# %%
class MaskedLossIntrinsicNetwork(object):
    def __init__(self, input_dimensions, dimensions, alpha_dimensions, learning_rate=1e-3, checkpoint_file=None):
        graph = tf.Graph()
        self.sess = tf.InteractiveSession(graph=graph)
        
        self.dimensions = dimensions
        self.params = {}
        
        #input will be 1024x1024x3
        self.inp = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        self.alphas = tf.placeholder(tf.float32, shape=[None,] + list(alpha_dimensions))
        self.expected_output = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        
        encoder_layers = self.get_encoder_layers(self.inp)
        mid_output = self.get_mid_output(encoder_layers[-1])
        self.output = self.get_decoder_output(mid_output, encoder_layers)
        
        self.squared_diff = tf.squared_difference(self.output, self.expected_output)
        self.loss = tf.reduce_mean(self.alphas*self.squared_diff)
        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
        if checkpoint_file:
            saver = tf.train.Saver()
            saver.restore(self.sess, checkpoint_file)
        else:
            init = tf.global_variables_initializer()
            self.sess.run(init)
    
    def create_weights(self, stage, layer_num):
        dims = self.dimensions[get_dimension_name(stage, layer_num)]
        input_depth, output_depth, stride, filter_size = \
            (dims[x] for x in ['input_depth', 'output_depth', 'stride', 'filter_size'])
#         W = tf.Variable(tf.random_normal([filter_size, filter_size, input_depth, output_depth]))
        W = tf.get_variable(get_weight_name(stage, layer_num), shape=[filter_size, filter_size, input_depth, output_depth], 
                            initializer=tf.contrib.layers.xavier_initializer())
        b = tf.Variable(tf.random_normal([output_depth]))
        self.params[get_weight_name(stage, layer_num)] = W
        self.params[get_bias_name(stage, layer_num)] = b
        return W, b, stride
        
    def get_encoder_layers(self, inpt):
        prev = inpt
        encoder_layers = []
        # encoder layers 0 to 2
        for layer_num in range(3):
            W, b, stride = self.create_weights(ENCODER, layer_num)
            prev = conv2d(prev, W, b, stride)
            encoder_layers.append(prev)
        return encoder_layers
    
    def get_mid_output(self, encoder_output):
        prev = encoder_output
        for layer_num in range(1):
            W, b, stride = self.create_weights(MID, layer_num)
            prev = conv2d(prev, W, b, stride)
        return prev
        
    def get_decoder_output(self, mid_outputs, encoder_layers):
        prev = mid_outputs
        for layer_num in range(3):
            W, b, stride = self.create_weights(DECODER, layer_num)
            if layer_num < 2:
                encoder_layer_input = encoder_layers[2 - layer_num]
                prev = tf.concat([prev, encoder_layer_input], axis=3)
                prev = deconv2d(prev, W, b, stride)
            else:
                prev = conv2d(prev, W, b, stride)
        return prev
    
    def fit_batch(self, inputs, output, alphas):
        _, loss = self.sess.run((self.optimizer, self.loss), feed_dict={self.inp : inputs, self.expected_output : output, self.alphas: alphas})
        
        return loss
    
    def train(self, lighted_inputs, alpha_inputs, delighted_data, epochs, batch_size=1, display_step=5):
        random.shuffle(lighted_inputs)
        n_samples = len(lighted_inputs)
        mean_losses = []
        for epoch in range(epochs):
            total_iter = n_samples // batch_size
            total_loss = 0
            for i in range(total_iter):
                meshes, inputs = zip(*lighted_inputs[i * batch_size : (i + 1) * batch_size])
                ameshes, ainputs = zip(*alpha_inputs[i * batch_size : (i + 1) * batch_size])
                inputs = np.asarray(inputs)
                expected_outputs = np.asarray([delighted_data[mesh] for mesh in meshes])
                ainputs = np.asarray(ainputs)
                
                loss = self.fit_batch(inputs, expected_outputs, ainputs)
                total_loss += loss
            mean_loss = total_loss / total_iter
            mean_losses.append(mean_loss)
            if (epoch + 1) % display_step == 0:
                print('epoch %s: loss=%.4f' % (epoch + 1, mean_loss))
                
    def predict(self, inputs):
        return self.sess.run(self.output, feed_dict={self.inp : inputs})
    
    def save(self, save_path):
        saver = tf.train.Saver()
        saver.save(self.sess, save_path)

# %%
class MaskedOutputIntrinsicNetwork(object):
    def __init__(self, input_dimensions, dimensions, alpha_dimensions, learning_rate=1e-3, checkpoint_file=None):
        graph = tf.Graph()
        self.sess = tf.InteractiveSession(graph=graph)
        
        self.dimensions = dimensions
        self.params = {}
        
        #input will be 1024x1024x3
        self.inp = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        self.alphas = tf.placeholder(tf.float32, shape=[None,] + list(alpha_dimensions))
        self.expected_output = tf.placeholder(tf.float32, shape=[None,] + list(input_dimensions))
        
        encoder_layers = self.get_encoder_layers(self.inp)
        mid_output = self.get_mid_output(encoder_layers[-1])
        self.output = self.get_decoder_output(mid_output, encoder_layers)
        
        self.loss = tf.reduce_mean(tf.squared_difference(self.output, self.expected_output))
        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
        if checkpoint_file:
            saver = tf.train.Saver()
            saver.restore(self.sess, checkpoint_file)
        else:
            init = tf.global_variables_initializer()
            self.sess.run(init)
    
    def create_weights(self, stage, layer_num):
        dims = self.dimensions[get_dimension_name(stage, layer_num)]
        input_depth, output_depth, stride, filter_size = \
            (dims[x] for x in ['input_depth', 'output_depth', 'stride', 'filter_size'])
#         W = tf.Variable(tf.random_normal([filter_size, filter_size, input_depth, output_depth]))
        W = tf.get_variable(get_weight_name(stage, layer_num), shape=[filter_size, filter_size, input_depth, output_depth], 
                            initializer=tf.contrib.layers.xavier_initializer())
        b = tf.Variable(tf.random_normal([output_depth]))
        self.params[get_weight_name(stage, layer_num)] = W
        self.params[get_bias_name(stage, layer_num)] = b
        return W, b, stride
        
    def get_encoder_layers(self, inpt):
        prev = inpt
        encoder_layers = []
        # encoder layers 0 to 2
        for layer_num in range(3):
            W, b, stride = self.create_weights(ENCODER, layer_num)
            prev = conv2d(prev, W, b, stride)
            encoder_layers.append(prev)
        return encoder_layers
    
    def get_mid_output(self, encoder_output):
        prev = encoder_output
        for layer_num in range(1):
            W, b, stride = self.create_weights(MID, layer_num)
            prev = conv2d(prev, W, b, stride)
        return prev
        
    def get_decoder_output(self, mid_outputs, encoder_layers):
        prev = mid_outputs
        for layer_num in range(3):
            W, b, stride = self.create_weights(DECODER, layer_num)
            if layer_num < 2:
                encoder_layer_input = encoder_layers[2 - layer_num]
                prev = tf.concat([prev, encoder_layer_input], axis=3)
                prev = deconv2d(prev, W, b, stride)
            else:
                prev = conv2d(prev, W, b, stride)
        return prev
    
    def fit_batch(self, inputs, output, alphas):
        _, loss = self.sess.run((self.optimizer, self.loss), feed_dict={self.inp : inputs, self.expected_output : output, self.alphas: alphas})
        
        return loss
    
    def train(self, lighted_inputs, alpha_inputs, delighted_data, epochs, batch_size=1, display_step=5):
        random.shuffle(lighted_inputs)
        n_samples = len(lighted_inputs)
        mean_losses = []
        for epoch in range(epochs):
            total_iter = n_samples // batch_size
            total_loss = 0
            for i in range(total_iter):
                meshes, inputs = zip(*lighted_inputs[i * batch_size : (i + 1) * batch_size])
                ameshes, ainputs = zip(*alpha_inputs[i * batch_size : (i + 1) * batch_size])
                inputs = np.asarray(inputs)
                expected_outputs = np.asarray([delighted_data[mesh] for mesh in meshes])
                ainputs = np.asarray(ainputs)
                
                loss = self.fit_batch(inputs, expected_outputs, ainputs)
                total_loss += loss
            mean_loss = total_loss / total_iter
            mean_losses.append(mean_loss)
            if (epoch + 1) % display_step == 0:
                print('epoch %s: loss=%.4f' % (epoch + 1, mean_loss))
                
    def predict(self, inputs):
        return self.sess.run(self.output, feed_dict={self.inp : inputs})
    
    def save(self, save_path):
        saver = tf.train.Saver()
        saver.save(self.sess, save_path)

# %%
network = IntrinsicNetwork((1024, 1024, 3), layer_dimensions)

# %%
masked_loss_network = MaskedLossIntrinsicNetwork((1024, 1024, 3), layer_dimensions, (1024, 1024, 1))

# %%
masked_output_network = MaskedOutputIntrinsicNetwork((1024, 1024, 3), layer_dimensions)

# %%
# Pass the alpha layer in at the conv output layer maybe 
# (as an additional component to the depth)

# %%
# Pass in the normalized to 0, 1 alpha layer as a mask to the loss
# dimension issues with placeholders
binarized_alphas = lighted_data[50:]
for i in range(len(binarized_alphas)):

    mesh, alphas = lighted_alpha_data[i]
    alphas = np.where(alphas > .5, 1.0, 0.0)
    alphas = np.resize(alphas, (alphas.shape[0], alphas.shape[1], 1))
    binarized_alphas[i] = (mesh, alphas)

# %%
print binarized_alphas[0][1].shape
# Out:
# (1024, 1024, 1)

# %%
masked_loss_network.train(lighted_data[50:], binarized_alphas, delighted_data, display_step=1, epochs=5, batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b32d4e70744f> in <module>()
# ----> 1 masked_loss_network.train(lighted_data[50:], binarized_alphas, delighted_data, display_step=1, epochs=5, batch_size=10)
#
# <ipython-input-23-74e12de865b3> in train(self, lighted_inputs, alpha_inputs, delighted_data, epochs, batch_size, display_step)
#      85                 ainputs = np.asarray(ainputs)
#      86
# ---> 87                 loss = self.fit_batch(inputs, expected_outputs, ainputs)
#      88                 total_loss += loss
#      89             mean_loss = total_loss / total_iter
#
# <ipython-input-23-74e12de865b3> in fit_batch(self, inputs, output, alphas)
#      67
#      68     def fit_batch(self, inputs, output, alphas):
# ---> 69         _, loss = self.sess.run((self.optimizer, self.loss), feed_dict={self.inp : inputs, self.expected_output : output, self.alphas: alphas})
#      70
#      71         return loss
#
# /Users/quinntran/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/quinntran/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/quinntran/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/quinntran/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/quinntran/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Pass in the normalized to 0, 1 alpha layer as a mask to the input
# masked inputs
binarized_masked_lighted_data = lighted_data[50:]

for i in range(len(binarized_masked_lighted_data)):
    mesh, meshes = binarized_masked_lighted_data[i]
    mesh, alphas = lighted_alpha_data[i]
    alphas = np.where(alphas > .5, 1.0, 0.0)

    for j in range(meshes.shape[2]):
        meshes[:,:,j] = meshes[:,:,j]*alphas#.astype(casting='same_kind')
    binarized_masked_lighted_data[i] = (mesh, meshes)

# %%
network.train(binarized_masked_lighted_data[50:], delighted_data, display_step=1, epochs=5, batch_size=10)
# Out:
# epoch 1: loss=1358.5708
# epoch 2: loss=1313.4597
# epoch 3: loss=1353.2728
# epoch 4: loss=1253.4089
# epoch 5: loss=1191.4141

# %%
label, img = lighted_data[0]
plt.imshow(img)
plt.show()
plt.imshow(delighted_data[label])
plt.show()
plt.imshow(float_to_uint8(network.predict(np.array([img])))[0])
plt.show()

# %%
# Pass in the alpha layer as a mask to the input
# masked inputs
masked_lighted_data = lighted_data[50:]
lighted_alpha_data[50:]
for i in range(len(masked_lighted_data)):
    mesh, meshes = masked_lighted_data[i]
    mesh, alphas = lighted_alpha_data[i]
    for j in range(meshes.shape[2]):
        meshes[:,:,j] *= alphas
    masked_lighted_data[i] = (mesh, meshes)

# %%
network.train(masked_lighted_data[50:], delighted_data, display_step=1, epochs=5, batch_size=10)
# Out:
# epoch 1: loss=1916.4595
# epoch 2: loss=1617.4372
# epoch 3: loss=1507.7101
# epoch 4: loss=1473.0457
# epoch 5: loss=1430.5780

# %%
label, img = lighted_data[0]
plt.imshow(img)
plt.show()
plt.imshow(delighted_data[label])
plt.show()
plt.imshow(float_to_uint8(network.predict(np.array([img])))[0])
plt.show()

# %%
network.train(lighted_data[50:], delighted_data, display_step=1, epochs=5, batch_size=10)
# Out:
# epoch 1: loss=1423.2117
# epoch 2: loss=806.8362
# epoch 3: loss=786.5836
# epoch 4: loss=788.7726
# epoch 5: loss=753.1980

# %%
label, img = lighted_data[0]
plt.imshow(img)
plt.show()
plt.imshow(delighted_data[label])
plt.show()
plt.imshow(float_to_uint8(network.predict(np.array([img])))[0])
plt.show()
